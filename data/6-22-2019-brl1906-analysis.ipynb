# %%
from data import dframe

# %%
dframe
# Out:
#                         agency        funding  avg_stipend  fringe  \
# 2014-01-01      Mayor's Office    Contractual        44000  9680.0
# 2014-01-01      Mayor's Office    Contractual        44000  9680.0
# 2015-01-01                MOED            BoE        44000  9680.0
# 2015-01-01                MOED            BoE        44000  9680.0
# 2015-01-01                BCHD            BoE        44000  9680.0
# 2015-01-01                BCHD            BoE        44000  9680.0
# 2015-01-01                BCHD            BoE        44000  9680.0
# 2015-01-01                BCHD            BoE        44000  9680.0
# 2015-01-01                BCHD            BoE        44000  9680.0
# 2015-01-01                BCHD            BoE        44000  9680.0
# 2016-01-01                BCHD            BoE        44000  9680.0
# 2016-01-01                BCHD            BoE        44000  9680.0
# 2016-01-01                BCHD            BoE        44000  9680.0
# ...
